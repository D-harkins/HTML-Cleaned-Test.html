# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as pl
import plotly.offline as py
py.init_notebook_mode(connected=True)
original_df=pd.read_csv('BTA_2022218.csv',sep=',', error_bad_lines=False, index_col=False, dtype='unicode');
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
original_df.head();
# Out:
#   member                     email listserv                     institute  \
# 0    Yes       cmalstead@gmail.com       No      Art Institute of Chicago
# 1     No                       NaN      NaN                           NaN
# 2    Yes       chanijohnson@me.com       No  North Carolina Museum of Art
# 3    Yes   clarkleerobin@gmail.com      Yes   Smith College Museum of Art
# 4    Yes  Jbusch@folkartmuseum.org       No      American Folk Art Museum
#
#   initiation_you                                initiation_existing  \
# 0            NaN  An existing trustee in your personal or profes...
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            You                                                NaN
#
#   intiation_trustee                        initation_director_personal  \
# ...

# %%
original_df.tail();
# Out:
#      member email listserv institute initiation_you initiation_existing  \
# 1539    NaN   NaN      NaN       NaN            NaN                 NaN
# 1540    NaN   NaN      NaN       NaN            NaN                 NaN
# 1541    NaN   NaN      NaN       NaN            NaN                 NaN
# 1542    NaN   NaN      NaN       NaN            NaN                 NaN
# 1543    NaN   NaN      NaN       NaN            NaN                 NaN
#
#      intiation_trustee initation_director_personal intiation_director_not  \
# 1539               NaN                         NaN                    NaN
# 1540               NaN                         NaN                    NaN
# 1541               NaN                         NaN                    NaN
# 1542               NaN                         NaN                    NaN
# 1543               NaN                         NaN                    NaN
#
#      initation_staff  ... finished  lat long committees race_original race  \
# ...

# %%
original_df.isnull();
# Out:
#       member  email  listserv  institute  initiation_you  initiation_existing  \
# 0      False  False     False      False            True                False
# 1      False   True      True       True            True                 True
# 2      False  False     False      False            True                 True
# 3      False  False     False      False            True                 True
# 4      False  False     False      False           False                 True
# ...      ...    ...       ...        ...             ...                  ...
# 1539    True   True      True       True            True                 True
# 1540    True   True      True       True            True                 True
# 1541    True   True      True       True            True                 True
# 1542    True   True      True       True            True                 True
# 1543    True   True      True       True            True                 True
#
# ...

# %%
original_df.isna().sum();
# Out:
# member                492
# email                 579
# listserv              579
# institute             676
# initiation_you       1486
#                      ...
# race                  579
# two_or_more          1527
# black_two_or_more    1525
# all_two_or_more      1508
# gender                584
# Length: 288, dtype: int64

# %%
original_df.isna().any().sum();
# Out:
# 288

# %%
original_df.fillna(value=0);
# Out:
#      member                     email listserv                     institute  \
# 0       Yes       cmalstead@gmail.com       No      Art Institute of Chicago
# 1        No                         0        0                             0
# 2       Yes       chanijohnson@me.com       No  North Carolina Museum of Art
# 3       Yes   clarkleerobin@gmail.com      Yes   Smith College Museum of Art
# 4       Yes  Jbusch@folkartmuseum.org       No      American Folk Art Museum
# ...     ...                       ...      ...                           ...
# 1539      0                         0        0                             0
# 1540      0                         0        0                             0
# 1541      0                         0        0                             0
# 1542      0                         0        0                             0
# 1543      0                         0        0                             0
#
# ...

# %%
original_df.drop(original_df[original_df['member']=='No'].index,inplace=True);

# %% [raw]
# original_df;

# %%
print(original_df.head());
# Out:
#   member                     email listserv                     institute  \
# 0    Yes       cmalstead@gmail.com       No      Art Institute of Chicago
# 2    Yes       chanijohnson@me.com       No  North Carolina Museum of Art
# 3    Yes   clarkleerobin@gmail.com      Yes   Smith College Museum of Art
# 4    Yes  Jbusch@folkartmuseum.org       No      American Folk Art Museum
# 5    Yes           ballaam@mac.com       No                           NaN
#
#   initiation_you                                initiation_existing  \
# 0            NaN  An existing trustee in your personal or profes...
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            You                                                NaN
# 5            NaN                                                NaN
#
#   intiation_trustee                        initation_director_personal  \
# ...

# %%
original_df;
# Out:
#      member                     email listserv                     institute  \
# 0       Yes       cmalstead@gmail.com       No      Art Institute of Chicago
# 2       Yes       chanijohnson@me.com       No  North Carolina Museum of Art
# 3       Yes   clarkleerobin@gmail.com      Yes   Smith College Museum of Art
# 4       Yes  Jbusch@folkartmuseum.org       No      American Folk Art Museum
# 5       Yes           ballaam@mac.com       No                           NaN
# ...     ...                       ...      ...                           ...
# 1539    NaN                       NaN      NaN                           NaN
# 1540    NaN                       NaN      NaN                           NaN
# 1541    NaN                       NaN      NaN                           NaN
# 1542    NaN                       NaN      NaN                           NaN
# 1543    NaN                       NaN      NaN                           NaN
#
# ...

# %%
original_df.dropna(how='all');
# Out:
#      member                        email listserv  \
# 0       Yes          cmalstead@gmail.com       No
# 2       Yes          chanijohnson@me.com       No
# 3       Yes      clarkleerobin@gmail.com      Yes
# 4       Yes     Jbusch@folkartmuseum.org       No
# 5       Yes              ballaam@mac.com       No
# ...     ...                          ...      ...
# 1047    Yes       Dellenwilson@gmail.com      Yes
# 1048    Yes      sljonesstudio@gmail.com       No
# 1051    Yes  christinejvincent@gmail.com       No
# 1542    NaN                          NaN      NaN
# 1543    NaN                          NaN      NaN
#
#                                     institute initiation_you  \
# 0                    Art Institute of Chicago            NaN
# 2                North Carolina Museum of Art            NaN
# 3                 Smith College Museum of Art            NaN
# 4                    American Folk Art Museum            You
# ...

# %%
original_df.dropna(how='all');
# Out:
#      member                        email listserv  \
# 0       Yes          cmalstead@gmail.com       No
# 2       Yes          chanijohnson@me.com       No
# 3       Yes      clarkleerobin@gmail.com      Yes
# 4       Yes     Jbusch@folkartmuseum.org       No
# 5       Yes              ballaam@mac.com       No
# ...     ...                          ...      ...
# 1047    Yes       Dellenwilson@gmail.com      Yes
# 1048    Yes      sljonesstudio@gmail.com       No
# 1051    Yes  christinejvincent@gmail.com       No
# 1542    NaN                          NaN      NaN
# 1543    NaN                          NaN      NaN
#
#                                     institute initiation_you  \
# 0                    Art Institute of Chicago            NaN
# 2                North Carolina Museum of Art            NaN
# 3                 Smith College Museum of Art            NaN
# 4                    American Folk Art Museum            You
# ...

# %%
original_df.fillna(value=0);
# Out:
#      member                     email listserv                     institute  \
# 0       Yes       cmalstead@gmail.com       No      Art Institute of Chicago
# 2       Yes       chanijohnson@me.com       No  North Carolina Museum of Art
# 3       Yes   clarkleerobin@gmail.com      Yes   Smith College Museum of Art
# 4       Yes  Jbusch@folkartmuseum.org       No      American Folk Art Museum
# 5       Yes           ballaam@mac.com       No                             0
# ...     ...                       ...      ...                           ...
# 1539      0                         0        0                             0
# 1540      0                         0        0                             0
# 1541      0                         0        0                             0
# 1542      0                         0        0                             0
# 1543      0                         0        0                             0
#
# ...

# %%
original_df_dedupped = original_df.drop('email', axis=1).drop_duplicates();

# %%
original_df_dedupped;
# Out:
#      member listserv                                institute initiation_you  \
# 0       Yes       No                 Art Institute of Chicago            NaN
# 2       Yes       No             North Carolina Museum of Art            NaN
# 3       Yes      Yes              Smith College Museum of Art            NaN
# 4       Yes       No                 American Folk Art Museum            You
# 5       Yes       No                                      NaN            NaN
# ...     ...      ...                                      ...            ...
# 1048    Yes       No  Indianapolis Museum of Art at Newfields            You
# 1051    Yes       No        Center for Maine Contemporary Art            NaN
# 1052    NaN      NaN                                      NaN            NaN
# 1542    NaN      NaN                                      NaN            NaN
# 1543    NaN      NaN                                      NaN            NaN
#
# ...

# %%
df2=original_df_dedupped.fillna(value="No Response");

# %%
df2;
# Out:
#            member     listserv                                institute  \
# 0             Yes           No                 Art Institute of Chicago
# 2             Yes           No             North Carolina Museum of Art
# 3             Yes          Yes              Smith College Museum of Art
# 4             Yes           No                 American Folk Art Museum
# 5             Yes           No                              No Response
# ...           ...          ...                                      ...
# 1048          Yes           No  Indianapolis Museum of Art at Newfields
# 1051          Yes           No        Center for Maine Contemporary Art
# 1052  No Response  No Response                              No Response
# 1542  No Response  No Response                              No Response
# 1543  No Response  No Response                              No Response
#
#      initiation_you                                initiation_existing  \
# ...

# %%
df2.shape;
# Out:
# (968, 287)

# %%
df2.isnull().sum();
# Out:
# member                 0
# listserv               0
# institute              0
# initiation_you         0
# initiation_existing    0
#                       ..
# race                   0
# two_or_more            0
# black_two_or_more      0
# all_two_or_more        0
# gender                 0
# Length: 287, dtype: int64

# %%
# remove special character
df2.columns = df2.columns.str.replace(' ', '');

# %%
df2;
# Out:
#            member     listserv                                institute  \
# 0             Yes           No                 Art Institute of Chicago
# 2             Yes           No             North Carolina Museum of Art
# 3             Yes          Yes              Smith College Museum of Art
# 4             Yes           No                 American Folk Art Museum
# 5             Yes           No                              No Response
# ...           ...          ...                                      ...
# 1048          Yes           No  Indianapolis Museum of Art at Newfields
# 1051          Yes           No        Center for Maine Contemporary Art
# 1052  No Response  No Response                              No Response
# 1542  No Response  No Response                              No Response
# 1543  No Response  No Response                              No Response
#
#      initiation_you                                initiation_existing  \
# ...

# %%
print(df2.columns.tolist());
# Out:
# ['member', 'listserv', 'institute', 'initiation_you', 'initiation_existing', 'intiation_trustee', 'initation_director_personal', 'intiation_director_not', 'initation_staff', 'initation_other', 'initation_text', 'pre-existing', 'orientation', 'influence_decision', 'prepared', 'initial_expectations', 'actual_experience', 'member_expectations_giving', 'member_expectations_asking', 'member_expectations_cultivate', 'member_expectations_sharing', 'member_expectations_fiscal', 'member_expectations_art', 'member_expectations_host', 'member_expectations_other', 'member_expectations_text', 'explanation_expectations', 'standard_giving_level', 'standard_giving_level_influence', 'at_standard_giving_level', 'asking_others', 'board_meetings', 'board_meetings_text', 'attend_board_meetings', 'essential', 'exp_values', 'satisfied', 'leaving', 'why_leaving', 'improve', 'word1', 'word2', 'word3', 'constituencies_fellow', 'constituencies_leadership', 'constituencies_staff', 'constituencies_visitors', 'co
# ...

# %%
df3=df2.drop(columns=['religion__', 'religion____', 'religion_____','religion_____.1','religion_______','why_leaving','word1', 'word2', 'word3']);

# %%
print(df3.columns.tolist());
# Out:
# ['member', 'listserv', 'institute', 'initiation_you', 'initiation_existing', 'intiation_trustee', 'initation_director_personal', 'intiation_director_not', 'initation_staff', 'initation_other', 'initation_text', 'pre-existing', 'orientation', 'influence_decision', 'prepared', 'initial_expectations', 'actual_experience', 'member_expectations_giving', 'member_expectations_asking', 'member_expectations_cultivate', 'member_expectations_sharing', 'member_expectations_fiscal', 'member_expectations_art', 'member_expectations_host', 'member_expectations_other', 'member_expectations_text', 'explanation_expectations', 'standard_giving_level', 'standard_giving_level_influence', 'at_standard_giving_level', 'asking_others', 'board_meetings', 'board_meetings_text', 'attend_board_meetings', 'essential', 'exp_values', 'satisfied', 'leaving', 'improve', 'constituencies_fellow', 'constituencies_leadership', 'constituencies_staff', 'constituencies_visitors', 'constituencies_nonboard_donors', 'constituen
# ...

# %%
df3;
# Out:
#            member     listserv                                institute  \
# 0             Yes           No                 Art Institute of Chicago
# 2             Yes           No             North Carolina Museum of Art
# 3             Yes          Yes              Smith College Museum of Art
# 4             Yes           No                 American Folk Art Museum
# 5             Yes           No                              No Response
# ...           ...          ...                                      ...
# 1048          Yes           No  Indianapolis Museum of Art at Newfields
# 1051          Yes           No        Center for Maine Contemporary Art
# 1052  No Response  No Response                              No Response
# 1542  No Response  No Response                              No Response
# 1543  No Response  No Response                              No Response
#
#      initiation_you                                initiation_existing  \
# ...

# %% [markdown]
# #### Race Count

# %%
temp_series=df3['race'].value_counts()
labels=(np.array(temp_series.index))
sizes=(np.array((temp_series/temp_series.sum())*100))
trace = go.Pie(labels=labels, values=sizes)
layout = go.Layout(
    title='Race Distribution'
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="race")
# Out:
# <div>                            <div id="3ddb1641-2029-41ae-a4f3-e67dc133f2fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ddb1641-2029-41ae-a4f3-e67dc133f2fd")) {                    Plotly.newPlot(                        "3ddb1641-2029-41ae-a4f3-e67dc133f2fd",                        [{"labels":["White or Caucasian ","Black","I prefer not to answer this question","Hispanic/ Latino/ Latina/ or Latinx ","Asian or Asian American ","Two or more","Other (please specify):","Middle Eastern or Northern African","No Response","American Indian or Alaska Native ","Native Hawaiian or Other Pacific Islander "],"values":[68.90495867768594,17.56198347107438,3.71900826446281,3.3057851239669422,3.202479338842975,1.756198347107438,0.6198347107438017,0.309917355
# ...

# %%
cnt_srs = df3['race'].value_counts()
trace = go.Bar(
    x=cnt_srs.index,
    y=cnt_srs.values,
    marker=dict(
        #color = np.random.randn(500), #set color equal to a variable
        color = cnt_srs.values,
        colorscale='earth',
        showscale=True
    ),
)
layout = go.Layout(
    title='Race distribution'
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="race")
# Out:
# <div>                            <div id="37fe62b7-9bd1-4f3a-b614-eec30b6346ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37fe62b7-9bd1-4f3a-b614-eec30b6346ac")) {                    Plotly.newPlot(                        "37fe62b7-9bd1-4f3a-b614-eec30b6346ac",                        [{"marker":{"color":[667,170,36,32,31,17,6,3,3,2,1],"colorscale":[[0.0,"rgb(161, 105, 40)"],[0.16666666666666666,"rgb(189, 146, 90)"],[0.3333333333333333,"rgb(214, 189, 141)"],[0.5,"rgb(237, 234, 194)"],[0.6666666666666666,"rgb(181, 200, 184)"],[0.8333333333333334,"rgb(121, 167, 172)"],[1.0,"rgb(40, 135, 161)"]],"showscale":true},"x":["White or Caucasian ","Black","I prefer not to answer this question","Hispanic/ Latino/ Latina/ or Latinx ","Asian or Asian America
# ...

# %%
cnt_srs = df3['institute'].value_counts().head(20)
trace = go.Bar(
    x=cnt_srs.index,
    y=cnt_srs.values,
    marker=dict(
        #color = np.random.randn(500), #set color equal to a variable
        color = cnt_srs.values,
        colorscale='earth',
        showscale=True
    ),
)
layout = go.Layout(
    title='Institute Count'
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="institute")
# Out:
# <div>                            <div id="0a5a9ff6-69c3-41f3-9609-e5ff56b8b0c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a5a9ff6-69c3-41f3-9609-e5ff56b8b0c4")) {                    Plotly.newPlot(                        "0a5a9ff6-69c3-41f3-9609-e5ff56b8b0c4",                        [{"marker":{"color":[100,25,24,23,22,21,20,19,18,18,18,16,16,16,15,15,15,15,14,14],"colorscale":[[0.0,"rgb(161, 105, 40)"],[0.16666666666666666,"rgb(189, 146, 90)"],[0.3333333333333333,"rgb(214, 189, 141)"],[0.5,"rgb(237, 234, 194)"],[0.6666666666666666,"rgb(181, 200, 184)"],[0.8333333333333334,"rgb(121, 167, 172)"],[1.0,"rgb(40, 135, 161)"]],"showscale":true},"x":["No Response","Crocker Art Museum","Minneapolis Institute of Art","Brooklyn Museum","Oakland Museum 
# ...

# %% [markdown]
# #### Education Level Count

# %%
cnt_srs = df3['education'].value_counts()

trace = go.Scatter(
    x=cnt_srs.index,
    y=cnt_srs.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 1,
        size = 50,
        #color = np.random.randn(500), #set color equal to a variable
        color = cnt_srs.values,
        colorscale='algae',
        showscale=True
    ),
)

layout = go.Layout(
    title='Education distribution'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="education")
# Out:
# <div>                            <div id="20b5d2d3-a59d-4054-a399-33f93355ba19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20b5d2d3-a59d-4054-a399-33f93355ba19")) {                    Plotly.newPlot(                        "20b5d2d3-a59d-4054-a399-33f93355ba19",                        [{"marker":{"color":[336,287,193,86,23,18,13,12],"colorscale":[[0.0,"rgb(214, 249, 207)"],[0.09090909090909091,"rgb(186, 228, 174)"],[0.18181818181818182,"rgb(156, 209, 143)"],[0.2727272727272727,"rgb(124, 191, 115)"],[0.36363636363636365,"rgb(85, 174, 91)"],[0.45454545454545453,"rgb(37, 157, 81)"],[0.5454545454545454,"rgb(7, 138, 78)"],[0.6363636363636364,"rgb(13, 117, 71)"],[0.7272727272727273,"rgb(23, 95, 61)"],[0.8181818181818182,"rgb(25, 75, 49)"],[0.90909090
# ...

# %% [markdown]
# #### Salary Count

# %%
cnt_srs = df3['salary'].value_counts()

trace = go.Scatter(
    x=cnt_srs.index,
    y=cnt_srs.values,
    mode='markers',
    marker=dict(
        sizemode = 'diameter',
        sizeref = 1,
        size = 50,
        #color = np.random.randn(500), #set color equal to a variable
        color = cnt_srs.values,
        colorscale='tropic',
        showscale=True
    ),
)

layout = go.Layout(
    title='salary distribution'
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="salary")
# Out:
# <div>                            <div id="ee83369b-0395-4a1f-9111-889b625906cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee83369b-0395-4a1f-9111-889b625906cf")) {                    Plotly.newPlot(                        "ee83369b-0395-4a1f-9111-889b625906cf",                        [{"marker":{"color":[317,289,93,73,61,61,43,26,5],"colorscale":[[0.0,"rgb(0, 155, 158)"],[0.16666666666666666,"rgb(66, 183, 185)"],[0.3333333333333333,"rgb(167, 211, 212)"],[0.5,"rgb(241, 241, 241)"],[0.6666666666666666,"rgb(228, 193, 217)"],[0.8333333333333334,"rgb(214, 145, 193)"],[1.0,"rgb(199, 93, 171)"]],"showscale":true,"size":50,"sizemode":"diameter","sizeref":1},"mode":"markers","x":["I prefer not to answer this question","$100,000 to $499,999","$500,000 t
# ...

# %% [markdown]
# #### Country Count

# %%
# remove special character
df2 ['country'] = df2 ['country'].str.replace(' ', '');

# %%
cnt_srs = df2['country'].value_counts()
pl.figure(figsize=(8,12))
sns.barplot(y=cnt_srs.index, x=cnt_srs.values, alpha=0.8)
pl.xlabel('Number of respondents', fontsize=12)
pl.ylabel('Country', fontsize=12)
pl.title("Country wise number of respondents", fontsize=15)
pl.show();

# %%
cnt_srs = df2['country'].value_counts()
trace = go.Bar(
    x=cnt_srs.index,
    y=cnt_srs.values,
    marker=dict(
        #color = np.random.randn(500), #set color equal to a variable
        color = cnt_srs.values,
        colorscale='armyrose',
        showscale=True
    ),
)
layout = go.Layout(
    title='Country Count'
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="country")
# Out:
# <div>                            <div id="2ff57c04-0001-49ad-b0e8-9db9f879a7e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ff57c04-0001-49ad-b0e8-9db9f879a7e7")) {                    Plotly.newPlot(                        "2ff57c04-0001-49ad-b0e8-9db9f879a7e7",                        [{"marker":{"color":[922,26,12,2,1,1,1,1,1,1],"colorscale":[[0.0,"rgb(121, 130, 52)"],[0.16666666666666666,"rgb(163, 173, 98)"],[0.3333333333333333,"rgb(208, 211, 162)"],[0.5,"rgb(253, 251, 228)"],[0.6666666666666666,"rgb(240, 198, 195)"],[0.8333333333333334,"rgb(223, 145, 163)"],[1.0,"rgb(212, 103, 128)"]],"showscale":true},"x":["USA","NoResponse","Canada","PuertoRico","SA,UK,USA","HongKong","UK","Germany","Brazil","Monaco"],"y":[922,26,12,2,1,1,1,1,1,1],"type":"
# ...

# %% [markdown]
# #### Satisfaction Count

# %%
colors = ['#B1EDED','#B1B2ED','#1DE7ED','#1DA5ED','#1D50ED','#16548E'];

# %%
fig = px.funnel_area(names=df3['satisfied'][1:].value_counts().index, values=df3['satisfied'][1:].value_counts().values, title='Satisfaction')
fig.update_traces(marker=dict(colors=colors[::1]))
fig.show()
# Out:
# <div>                            <div id="f6a341c0-1361-46fe-9644-121719b1de80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6a341c0-1361-46fe-9644-121719b1de80")) {                    Plotly.newPlot(                        "f6a341c0-1361-46fe-9644-121719b1de80",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Agree","Strongly agree","Neither agree nor disagree","Disagree","No Response","Strongly disagree"],"legendgroup":"","name":"","showlegend":true,"values":[502,342,91,20,7,5],"type":"funnelarea","marker":{"colors":["#B1EDED","#B1B2ED","#1DE7ED","#1DA5ED","#1D50ED","#16548E"]}}],                        {"template":{"data":{"bar":[{"error_x":{"color":"
# ...

# %% [markdown]
# #### Committees

# %%
comm_analysis = ['building_comm','collections_comm','community_comm','dei_comm','executive_comm','standalone_comm','audit_comm','fundraising_comm','gov_comm','investment_comm','special_comm','other_comm','none_comm','committees_text', 'director_comm', 'committees','race_native', 'race_asian', 'race_black', 'race_hispanic', 'race_mid_east', 'race_hawaiian', 'race_white', 'race_other', 'race_prefer_no', 'race_text', 'gender_agender', 'gender_nonconform', 'gender_man', 'gender_nonbinary', 'gender_woman', 'gender_other', 'gender_prefer_no', 'gender_text', 'trans', 'sexual_orientation_asexual', 'sexual_orientation_bisexual', 'sexual_orientation_gay', 'sexual_orientation_lesbian', 'sexual_orientation_pan', 'sexual_orientation_queer', 'sexual_orientation_hetero', 'sexual_orientation_other', 'sexual_orientation_prefer_no', 'sexual_orientation_text', 'disability', 'religion_agnostic', 'religion_athiest', 'religion_bahai', 'religion_baptist', 'religion_buddhist', 'religion_catholic', 'religion_church_of_christ', 'religion_christ_non_d', 'religion_', 'religion_episcopalian', 'religion_eastern_orth', 'religion_hindu', 'religion_jehovah', 'religion_jewish_conservative', 'religion_jewish_ortho', 'religion_jewish_reform', 'religion_jewish_other', 'religion_lutheran', 'religion_methodist', 'religion_muslim_sunni', 'religion_muslim_other', 'religion_pentecostal', 'religion_presb', 'religion_prote', 'religion_quaker', 'religion_seventh', 'religion______', 'religion_unitarian', 'religion_ucc', 'religion_other', 'religion_none', 'religion_prefer_no', 'religion_jewish_text', 'religion_muslim_text', 'religion_text', 'year_born', 'country', 'zipcode', 'occupation_animal_care', 'occupation_apparel', 'occupation_architecture', 'occupation_art', 'occupation_assembly_fab', 'occupation_building_clean', 'occupation_business', 'occupation_comm_serv', 'occupation_tech', 'occupation_construction', 'occupation_design', 'occupation_edu', 'occupation_engine', 'occupation_entertain', 'occupation_farm', 'occupation_finance', 'occupation_food_prep', 'occupation_food_proc', 'occupation_furnish', 'occupation_health', 'occupation_repair', 'occupation_legal', 'occupation_libraries', 'occupation_life_science', 'occupation_maint', 'occupation_math', 'occupation_medi', 'occupation__', 'occupation_office_admin', 'occupation_personal', 'occupation_physical_science', 'occupation_protective', 'occupation_sales', 'occupation_social_science', 'occupation_social_service', 'occupation_sports', 'occupation_transp', 'occupation_other', 'occupation_prefer_no', 'occupation_text', 'artist', 'salary', 'additional_income_spouse', 'additional_income_family', 'additional_income_jobs', 'additional_income_investments', 'additional_income_other', 'additional_income_prefer_no', 'additional_income_text', 'family_board_art_museum', 'family_board_museum', 'family_board_other', 'family_board_prefer_no', 'family_board_na', 'education', 'first_generation', 'interview', 'source', 'finished', 'lat', 'long', 'committees', 'race_original', 'race', 'two_or_more', 'black_two_or_more', 'all_two_or_more', 'gender'];

# %%
df_comm = df3[comm_analysis].drop(['committees_text'],axis=1);

# %%
df_comm;
# Out:
#      building_comm collections_comm community_comm     dei_comm  \
# 0      No Response      No Response    No Response  No Response
# 2      No Response      No Response    No Response  No Response
# 3      No Response                1    No Response            1
# 4                1                1              1  No Response
# 5                1                1    No Response            1
# ...            ...              ...            ...          ...
# 1048   No Response      No Response    No Response  No Response
# 1051   No Response      No Response    No Response  No Response
# 1052   No Response      No Response    No Response  No Response
# 1542   No Response      No Response    No Response  No Response
# 1543   No Response      No Response              1  No Response
#
#      executive_comm standalone_comm   audit_comm fundraising_comm  \
# 0       No Response     No Response  No Response      No Response
# ...

# %%
fig_invest_gen=px.histogram(df_comm, x='gender', y='investment_comm', histnorm='', color= 'gender', nbins=10, title='Investment Committee By Gender')
fig_invest_gen.show()
# Out:
# <div>                            <div id="4b7a8b86-fd29-4fc4-b009-c1642f57bf3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b7a8b86-fd29-4fc4-b009-c1642f57bf3a")) {                    Plotly.newPlot(                        "4b7a8b86-fd29-4fc4-b009-c1642f57bf3a",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","histnorm":"","hovertemplate":"gender=%{x}<br> weighted by investment_comm=%{y}<extra></extra>","legendgroup":"Man","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Man","nbinsx":10,"offsetgroup":"Man","orientation":"v","showlegend":true,"x":["Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man","Man",
# ...

# %%
fig_invest_race=px.histogram(df_comm, x='race', y='investment_comm', histnorm='', color= 'race', nbins=10, title='Investment Committee By Race')
fig_invest_race.show()
# Out:
# <div>                            <div id="9d3eda16-2f55-44eb-a422-117bfc598eba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d3eda16-2f55-44eb-a422-117bfc598eba")) {                    Plotly.newPlot(                        "9d3eda16-2f55-44eb-a422-117bfc598eba",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","histnorm":"","hovertemplate":"race=%{x}<br> weighted by investment_comm=%{y}<extra></extra>","legendgroup":"White or Caucasian ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"White or Caucasian ","nbinsx":10,"offsetgroup":"White or Caucasian ","orientation":"v","showlegend":true,"x":["White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ",
# ...

# %%
fig_gov_race=px.histogram(df_comm, x='race', y='gov_comm', histnorm='', color= 'race',  nbins=10, title='Governance Committee By Race')
fig_gov_race.show()
# Out:
# <div>                            <div id="f8032f1d-60a1-4ff0-af58-f01ab5e0a45e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8032f1d-60a1-4ff0-af58-f01ab5e0a45e")) {                    Plotly.newPlot(                        "f8032f1d-60a1-4ff0-af58-f01ab5e0a45e",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","histnorm":"","hovertemplate":"race=%{x}<br> weighted by gov_comm=%{y}<extra></extra>","legendgroup":"White or Caucasian ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"White or Caucasian ","nbinsx":10,"offsetgroup":"White or Caucasian ","orientation":"v","showlegend":true,"x":["White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","White 
# ...

# %%
fig_director_race=px.histogram(df_comm, x='race', y='director_comm', histnorm='', color= 'race',  nbins=10, title='Director Search Committee By Race')
fig_director_race.show()
# Out:
# <div>                            <div id="f31946ba-435c-4f6d-9f03-39225c102b26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f31946ba-435c-4f6d-9f03-39225c102b26")) {                    Plotly.newPlot(                        "f31946ba-435c-4f6d-9f03-39225c102b26",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","histnorm":"","hovertemplate":"race=%{x}<br> weighted by director_comm=%{y}<extra></extra>","legendgroup":"White or Caucasian ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"White or Caucasian ","nbinsx":10,"offsetgroup":"White or Caucasian ","orientation":"v","showlegend":true,"x":["White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","W
# ...

# %%
fig_executive_race=px.histogram(df_comm, x='race', y='executive_comm', histnorm='', color= 'race',  nbins=10, title='Executive Committee By Race')
fig_executive_race.show()
# Out:
# <div>                            <div id="552210e0-e63a-486f-aaee-3971da1ee3dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("552210e0-e63a-486f-aaee-3971da1ee3dd")) {                    Plotly.newPlot(                        "552210e0-e63a-486f-aaee-3971da1ee3dd",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","histnorm":"","hovertemplate":"race=%{x}<br> weighted by executive_comm=%{y}<extra></extra>","legendgroup":"White or Caucasian ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"White or Caucasian ","nbinsx":10,"offsetgroup":"White or Caucasian ","orientation":"v","showlegend":true,"x":["White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","
# ...

# %%
fig_fund_race=px.histogram(df_comm, x='race', y='fundraising_comm', histnorm='', color= 'race',  nbins=10, title='Fundraising Committee By Race')
fig_fund_race.show()
# Out:
# <div>                            <div id="35f8c6df-0a88-4de2-91d9-404cc6238d25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35f8c6df-0a88-4de2-91d9-404cc6238d25")) {                    Plotly.newPlot(                        "35f8c6df-0a88-4de2-91d9-404cc6238d25",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","histnorm":"","hovertemplate":"race=%{x}<br> weighted by fundraising_comm=%{y}<extra></extra>","legendgroup":"White or Caucasian ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"White or Caucasian ","nbinsx":10,"offsetgroup":"White or Caucasian ","orientation":"v","showlegend":true,"x":["White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian "
# ...

# %%
fig_acq_race=px.histogram(df_comm, x='race', y='collections_comm', histnorm='', color= 'race',  nbins=10, title='Collections & Acquistions Committee By Race')
fig_acq_race.show()
# Out:
# <div>                            <div id="441f6786-ce25-4f26-b182-9d5116003049" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("441f6786-ce25-4f26-b182-9d5116003049")) {                    Plotly.newPlot(                        "441f6786-ce25-4f26-b182-9d5116003049",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","histnorm":"","hovertemplate":"race=%{x}<br> weighted by collections_comm=%{y}<extra></extra>","legendgroup":"White or Caucasian ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"White or Caucasian ","nbinsx":10,"offsetgroup":"White or Caucasian ","orientation":"v","showlegend":true,"x":["White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian ","White or Caucasian "
# ...

# %%
layout = dict(title='Test',
              geo = dict(scope='zipcode',projection = dict(type ='albers usa'),
                        showlakes =True,lakecolor='rgb(66,165,245)'))

layout;
# Out:
# {'title': 'Test',
#  'geo': {'scope': 'zipcode',
#   'projection': {'type': 'albers usa'},
#   'showlakes': True,
#   'lakecolor': 'rgb(66,165,245)'}}

# %%
pip install chart_studio;
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import chart_studio
chart_studio.tools.set_credentials_file(username='Deirdre97', api_key='sQ5hN7Rzx4GrtyJJyOMU')
chart_studio.tools.set_config_file(world_readable=False, sharing='private');

# %%
pip install geopandas;
# Out:
# ...
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# ...
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
# ...

# %%
df3['count']=1;

# %%
# create trace 1 that is 3d scatter
trace1 = go.Scatter3d(
    x=df3.satisfied,
    y=df3.gender,
    z=df3.race,
    mode='markers',
    marker=dict(
        size=10,
        color='violet',                # set color to an array/list of desired values      
    )
)

data = [trace1]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0  
    )
    
)
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="2f33acc7-aa70-4bfa-a334-26e4881b98bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f33acc7-aa70-4bfa-a334-26e4881b98bd")) {                    Plotly.newPlot(                        "2f33acc7-aa70-4bfa-a334-26e4881b98bd",                        [{"marker":{"color":"violet","size":10},"mode":"markers","x":["No Response","Strongly agree","Strongly agree","Strongly agree","Disagree","Strongly agree","Agree","Strongly agree","Agree","Agree","Strongly agree","Strongly agree","Strongly agree","Agree","Agree","Agree","Agree","Strongly agree","Strongly agree","Agree","Strongly agree","Agree","Agree","Agree","Agree","Agree","Agree","Agree","Strongly agree","Agree","Agree","Agree","Strongly agree","Agree","Agree",
# ...

# %%
df3.to_csv('Cleaned Data.csv');

# %%
df4=df3.sort_values('year_born');

# %%
df4=df4.loc[df4['year_born']!='No Response'];

# %%
df4=df4.sort_values('year_born');

# %%
fig_year=px.histogram(df4, x='year_born', histnorm='', nbins=10, title='Year Born Frequency')
fig_year.update_xaxes(rangeslider_visible=True)
fig_year.show()
fig_year.write_html("testing.html")
# Out:
# <div>                            <div id="2568082a-9254-4a59-8940-dc3d232a4532" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2568082a-9254-4a59-8940-dc3d232a4532")) {                    Plotly.newPlot(                        "2568082a-9254-4a59-8940-dc3d232a4532",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"","hovertemplate":"year_born=%{x}<br>=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":10,"offsetgroup":"","orientation":"v","showlegend":false,"x":["1900","1924","1926","1928","1930","1930","1931","1931","1932","1932","1932","1933","1933","1933","1934","1935","1935","1935","1935","1935","1935","1936","1936","1936","1937","1937","1937","1937","1937","19
# ...
